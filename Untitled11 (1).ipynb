# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# !unzip "UCI HAR Dataset.zip"
# Out:
# --2024-12-11 20:33:12--  https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘UCI HAR Dataset.zip’
#
# UCI HAR Dataset.zip     [            <=>     ]  58.17M  18.5MB/s    in 3.1s
#
# 2024-12-11 20:33:16 (18.5 MB/s) - ‘UCI HAR Dataset.zip’ saved [60999314]
#
# Archive:  UCI HAR Dataset.zip
#    creating: UCI HAR Dataset/
#   inflating: UCI HAR Dataset/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/UCI HAR Dataset/
#   inflating: __MACOSX/UCI HAR Dataset/._.DS_Store
#   inflating: UCI HAR Dataset/activity_labels.txt
#   inflating: __MACOSX/UCI HAR Dataset/._activity_labels.txt
#   inflating: UCI HAR Dataset/features.txt
#   inflating: __MACOSX/UCI HAR Dataset/._features.txt
# ...

# %%
import pandas as pd
import numpy as np

# Load the training data
x_train = pd.read_csv('./UCI HAR Dataset/train/X_train.txt', delim_whitespace=True, header=None)
y_train = pd.read_csv('./UCI HAR Dataset/train/y_train.txt', delim_whitespace=True, header=None)

# Load the test data
x_test = pd.read_csv('./UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)
y_test = pd.read_csv('./UCI HAR Dataset/test/y_test.txt', delim_whitespace=True, header=None)

# Combine train and test for simplicity
x = pd.concat([x_train, x_test])
y = pd.concat([y_train, y_test])

# Convert labels to one-hot encoding
y = pd.get_dummies(y[0]).values
# Out:
# <ipython-input-7-3ba26d6b8b4f>:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   x_train = pd.read_csv('./UCI HAR Dataset/train/X_train.txt', delim_whitespace=True, header=None)
# <ipython-input-7-3ba26d6b8b4f>:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   y_train = pd.read_csv('./UCI HAR Dataset/train/y_train.txt', delim_whitespace=True, header=None)
# <ipython-input-7-3ba26d6b8b4f>:9: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   x_test = pd.read_csv('./UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None)
# ...

# %%
# Load raw data for a specific activity (e.g., Walking)
activity_index = 0  # Index of the activity sample to visualize
sample_activity_data = x_train[activity_index, :].reshape(-1)  # Reshape to a 1D array

# Plot the first 100 time steps of the sample
plt.figure(figsize=(10, 6))
plt.plot(sample_activity_data[:100], label='Sensor Reading', color='blue')
plt.title('Sensor Data for Sample Activity')
plt.xlabel('Time Steps')
plt.ylabel('Sensor Reading')
plt.legend()
plt.show()

# %%
from tensorflow.keras import layers, models

def build_har_model(input_shape, num_classes):
    model = models.Sequential([
        layers.Conv1D(64, kernel_size=3, activation='relu', input_shape=input_shape),
        layers.MaxPooling1D(pool_size=2),
        layers.Conv1D(128, kernel_size=3, activation='relu'),
        layers.MaxPooling1D(pool_size=2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# Build the model
input_shape = (x.shape[1], 1)  # Number of features
num_classes = y.shape[1]
model = build_har_model(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 559, 64)             │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 279, 64)             │               0 │
# ...

# %%
from sklearn.model_selection import train_test_split

# Reshape the data for Conv1D
x = x.values.reshape(x.shape[0], x.shape[1], 1)

# Split data
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# Train the model
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=20, batch_size=64)
# Out:
# Epoch 1/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.6106 - loss: 0.9116 - val_accuracy: 0.9160 - val_loss: 0.2058
# Epoch 2/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9136 - loss: 0.2230 - val_accuracy: 0.9699 - val_loss: 0.0902
# Epoch 3/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9396 - loss: 0.1566 - val_accuracy: 0.9650 - val_loss: 0.0847
# Epoch 4/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9565 - loss: 0.1104 - val_accuracy: 0.9743 - val_loss: 0.0674
# Epoch 5/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9718 - loss: 0.0842 - val_accuracy: 0.9777 - val_loss: 0.0590
# Epoch 6/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9692 - loss: 0.0771 - val_accuracy: 0.9796 - val_loss: 0.0494
# Epoch 7/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9762 - loss: 0.0659 - val_accuracy: 0.9835 - val_loss: 0.0393
# Epoch 8/20
# ...

# %%
loss, accuracy = model.evaluate(x_val, y_val)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9907 - loss: 0.0245
# Validation Accuracy: 98.79%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict labels
y_pred = model.predict(x_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_val, axis=1)

# Confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step

# %%
def plot_training_curves(history):
    plt.figure(figsize=(12, 6))

    # Plot Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()

    plt.show()

plot_training_curves(history)

# %%
# Test with sample data
sample_data = x_val[:5]  # Get the first 5 samples from the validation set
sample_labels = y_val[:5]  # True labels for the samples

# Predict the labels
predictions = model.predict(sample_data)
predicted_classes = np.argmax(predictions, axis=1)  # Get the class with highest probability
true_classes = np.argmax(sample_labels, axis=1)  # True class labels

# Map activity labels (if label names are provided in the dataset)
activity_labels = ['Walking', 'Walking Upstairs', 'Walking Downstairs', 'Sitting', 'Standing', 'Laying']

# Display results
for i in range(len(sample_data)):
    print(f"Sample {i+1}:")
    print(f"  True Activity: {activity_labels[true_classes[i]]}")
    print(f"  Predicted Activity: {activity_labels[predicted_classes[i]]}")
    print("\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# Sample 1:
#   True Activity: Walking
#   Predicted Activity: Walking
#
#
# Sample 2:
#   True Activity: Laying
#   Predicted Activity: Laying
#
#
# Sample 3:
#   True Activity: Standing
#   Predicted Activity: Standing
#
#
# Sample 4:
#   True Activity: Standing
#   Predicted Activity: Standing
#
#
# Sample 5:
#   True Activity: Walking
#   Predicted Activity: Walking

# %%
import time

# Simulate real-time predictions
for i in range(10):  # Simulate 10 time steps
    random_sample = np.expand_dims(x_val[i], axis=0)  # Take a random validation sample
    predicted_class = np.argmax(model.predict(random_sample), axis=1)
    print(f"Time Step {i+1}: Predicted Activity - {activity_labels[predicted_class[0]]}")
    time.sleep(1)  # Wait 1 second to simulate real-time
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Time Step 1: Predicted Activity - Walking
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Time Step 2: Predicted Activity - Laying
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Time Step 3: Predicted Activity - Standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Time Step 4: Predicted Activity - Standing
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Time Step 5: Predicted Activity - Walking
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Time Step 6: Predicted Activity - Walking
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Time Step 7: Predicted Activity - Walking
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Time Step 8: Predicted Activity - Sitting
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Time Step 9: Predicted Activity - Walking Upstairs
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Time Step 10: Predicted Activity - Laying

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report

# Flatten the data for Naive Bayes (since it cannot handle 3D input)
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_val_flat = x_val.reshape(x_val.shape[0], -1)

# Train Naive Bayes model
nb_model = GaussianNB()
nb_model.fit(x_train_flat, y_train.argmax(axis=1))

# Make predictions
y_pred_nb = nb_model.predict(x_val_flat)

# Evaluate Naive Bayes model
print("Naive Bayes Classification Report:")
print(classification_report(y_val.argmax(axis=1), y_pred_nb, target_names=['Walking', 'Walking Upstairs', 'Walking Downstairs', 'Sitting', 'Standing', 'Laying']))
# Out:
# Naive Bayes Classification Report:
#                     precision    recall  f1-score   support
#
#            Walking       0.93      0.72      0.81       369
#   Walking Upstairs       0.66      0.91      0.76       270
# Walking Downstairs       0.76      0.76      0.76       284
#            Sitting       0.55      0.89      0.68       377
#           Standing       0.81      0.33      0.47       354
#             Laying       0.99      0.87      0.93       406
#
#           accuracy                           0.75      2060
#          macro avg       0.78      0.75      0.74      2060
#       weighted avg       0.79      0.75      0.74      2060

# %%
from sklearn.metrics import classification_report

# Predict the labels for the validation set
y_pred = model.predict(x_val)
y_pred_classes = np.argmax(y_pred, axis=1)  # Get the class with the highest probability
y_true_classes = np.argmax(y_val, axis=1)  # Get the true class labels

# Generate the classification report
activity_labels = ['Walking', 'Walking Upstairs', 'Walking Downstairs', 'Sitting', 'Standing', 'Laying']
report = classification_report(y_true_classes, y_pred_classes, target_names=activity_labels)

print("CNN Classification Report:")
print(report)
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# CNN Classification Report:
#                     precision    recall  f1-score   support
#
#            Walking       1.00      1.00      1.00       369
#   Walking Upstairs       1.00      1.00      1.00       270
# Walking Downstairs       1.00      1.00      1.00       284
#            Sitting       0.99      0.95      0.97       377
#           Standing       0.95      0.99      0.97       354
#             Laying       1.00      1.00      1.00       406
#
#           accuracy                           0.99      2060
#          macro avg       0.99      0.99      0.99      2060
#       weighted avg       0.99      0.99      0.99      2060
